# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_column', 50)
pd.set_option('display.max_colwidth',80)

plt.style.use('seaborn-v0_8-whitegrid')

# %%
#Read Dataset

df = pd.read_csv(r'C:\Users\Njeri.Maina\Desktop\projects\Salary_Project\data\raw\Developer_survey_2025.csv',low_memory=False)

print(f"shape:{df.shape}")
print(f'First 5 column names:{list(df.columns[-5:])}')
# Out:
# shape:(49191, 172)
# First 5 column names:['AIAgentExtWrite', 'AIHuman', 'AIOpen', 'ConvertedCompYearly', 'JobSat']

# %%
target_col = 'ConvertedCompYearly'
print(f'Does the column actually exist: {target_col in df.columns}')
# Out:
# Does the column actually exist: True

# %%
#Shape

df.shape
# Out:
# (49191, 172)

# %%
df.info
# Out:
# <bound method DataFrame.info of        ResponseId  \
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 49186       49187
# 49187       49188
# 49188       49189
# 49189       49190
# 49190       49191
#
#                                                                             MainBranch  \
# 0                                                       I am a developer by profession
# 1                                                       I am a developer by profession
# 2                                                       I am a developer by profession
# 3                                                       I am a developer by profession
# 4                                                       I am a developer by profession
# ...                                                                                ...
# 49186                                                      I code primarily as a hobby
# ...

# %%
df.describe().T
# Out:
#                        count          mean           std  min      25%  \
# ResponseId           49191.0  2.459600e+04  1.420036e+04  1.0  12298.5
# WorkExp              42893.0  1.336740e+01  1.080012e+01  1.0      5.0
# YearsCode            43042.0  1.657086e+01  1.178761e+01  1.0      8.0
# TechEndorse_1        35975.0  7.867352e+00  2.397432e+00  1.0      7.0
# TechEndorse_2        35975.0  4.104211e+00  2.275821e+00  1.0      2.0
# TechEndorse_3        35975.0  4.110271e+00  2.329536e+00  1.0      2.0
# TechEndorse_4        35975.0  5.678193e+00  2.398084e+00  1.0      4.0
# TechEndorse_5        35975.0  4.119388e+00  2.437945e+00  1.0      2.0
# TechEndorse_6        35975.0  5.225990e+00  2.801045e+00  1.0      3.0
# TechEndorse_7        35975.0  6.477387e+00  2.331468e+00  1.0      5.0
# TechEndorse_8        35975.0  4.370841e+00  2.357058e+00  1.0      2.0
# TechEndorse_9        35975.0  4.431661e+00  2.620901e+00  1.0      2.0
# ...

# %%
df.isnull().sum()
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# EdLevel                 1042
# Employment               852
#                        ...
# AIAgentExtWrite        48332
# AIHuman                19997
# AIOpen                 26651
# ConvertedCompYearly    25244
# JobSat                 22521
# Length: 172, dtype: int64
